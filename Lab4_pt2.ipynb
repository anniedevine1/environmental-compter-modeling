# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
lat_min = 33;
lat_max = 42;
lon_min = -125;
lon_max = -115;

# %%
CAC = np.loadtxt('CA_coast_line_no_islands.txt', usecols=(0,1)) 
CAB = np.loadtxt('CA_boundary2.txt', usecols=(0,1)) 
print(CAC.shape,CAB.shape)
# Out:
# (1282, 2) (1295, 2)

# %%
CAC1 = np.append( CAC,  [[lon_min,max(CAC[:,1])]],axis=0)
CAC2 = np.append( CAC1, [[lon_min,min(CAC[:,1])]],axis=0)
ocean = CAC2.copy()

# %%
plate = np.loadtxt('plate.txt', usecols=(0,1)) 
print(plate.shape)
# Out:
# (925, 2)

# %%
#lat_UCB = 37+52/60+19.54/3600;
#lat_LAX = 33+56/60+38.89/3600;
lat_LAX = 33.9416
lon_LAX = -118.4085
lat_UCB = 37.8716
lon_UCB = -122.2727

# %%
plt.rcParams['figure.figsize'] = [15, 12]

plt.plot(CAB[:,0],CAB[:,1],'k-',lw=3)
plt.fill(CAB[:,0],CAB[:,1],'navajowhite')

#plt.fill(land[:,0],land[:,1],'-',color='lightgrey')
plt.fill(ocean[:,0],ocean[:,1],'-',color='lightblue')

plt.plot(plate[:,0],plate[:,1],'r-')
plt.fill(plate[:,0],plate[:,1],'pink')

plt.plot(lon_LAX,lat_LAX,'o',color='darkgreen',ms=20)
plt.plot(lon_UCB,lat_UCB,'*',mec='darkblue',mew=3,mfc='yellow',ms=40)

plt.grid(color='k', linestyle='-', linewidth=0.5)
plt.show()

# %%
#the two first plt commands create a line for the outline of california and color the land east of california white.

# %%
#the third plt command fills the ocean with blue

# %%
#the fourth and fifth plt commands create the coundary for the tectonic plate and then fill it with pink

# %%
#the next two commands plot the coordinates of LAX airport and UC Berkeley, with a green dot and yellow star

# %%
#the last plt command lays a grid on top of the entire graph

# %%
#the surface area of california is 403,466 km^2, to compute this, reiman sums of California could be taken to come up with an approximate area.
